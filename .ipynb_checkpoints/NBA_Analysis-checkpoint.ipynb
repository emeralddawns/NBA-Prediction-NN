# %% [markdown]
# # TO DO
#
# 0) Add more evaluations
# 1) Research how to make dimensionality reduction work and still be able to get a prediction
# 2) Move desired current prediction to the top of the sheet

# %% [markdown]
# ### Current Parameters:
# <a name='Parameters' />

# %%
use_post_season = "yes" # "yes" means yes, all else is no

# Number of Neurons
neurons_1 = 27
neurons_2 = 10
neurons_3 = 10
neurons_4 = 1

# Activation Types
activation_1 = "relu" # Original: "relu"
activation_2 = "relu"
activation_3 = "relu"
activation_4 = "sigmoid"
activation_outer = "sigmoid"

# Dropout Layer - Rate is the fraction of the inputs to drop between 0 and 1. 0 is none dropped
dropout_rate_1 = .30
dropout_rate_2 = .20
dropout_rate_3 = .20
dropout_rate_4 = .00

# Specify Learning Rate - Default is 0.001
alpha = .00125

# Number of Epochs
num_epochs = 20 # ~20 seems to yield the best results

# %% [markdown]
# ### Import Dependencies

# %%
# !pip install seaborn

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from tensorflow.keras.models import load_model
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sqlalchemy import create_engine
from scipy.stats import pearsonr

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import seaborn as sns
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import os
import joblib

# %%
# from numpy.random import seed seed(42) # keras seed fixing import tensorflow as tf 
# tf.random.set_seed(42) # tensorflow seed fixing

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Extracting from the Database

# %%
rds_connection_string = f"postgres:postgres@localhost:5432/group_2_project_4"
engine = create_engine(f"postgresql://{rds_connection_string}")

nba_df = pd.read_sql_query('select * from reg_season_matches', con=engine)
nba_post = pd.read_sql_query('select * from post_season_matches', con=engine)
reg_season_compiled = pd.read_sql_query('select * from reg_season_stats', con=engine)
post_season_compiled = pd.read_sql_query('select * from post_season_stats', con=engine)

name_abbv = pd.read_sql_query('select * from teams', con=engine)

# %%
# post_season_compiled
# reg_season_compiled 
nba_df
# nba_post
# name_abbv
# Out:
#      team type opponent w_l  min  pts  fgm  fga  threepm  threepa  ...  fta  \
# 0     MIN   vs      CHI   L  240  120   46   91       11       31  ...   22
# 1     CHI    @      MIN   W  240  124   44   83       10       21  ...   33
# 2     PHI   vs      DET   W  240  118   46   88        5       25  ...   23
# 3     DET    @      PHI   L  240  106   38   83       11       34  ...   29
# 4     MEM   vs      BOS   L  240  110   39  102       15       47  ...   27
# ...   ...  ...      ...  ..  ...  ...  ...  ...      ...      ...  ...  ...
# 2455  CHA    @      IND   W  240  123   46  107       13       31  ...   27
# 2456  BKN   vs      MIL   L  240  104   37   84       17       32  ...   23
# 2457  MIL    @      BKN   W  240  127   48  105       17       45  ...   18
# 2458  LAL   vs      GSW   L  240  114   45   95       15       42  ...   19
# 2459  GSW    @      LAL   W  240  121   41   93       14       39  ...   30
#
#       oreb  dreb  reb  ast  stl  blk  tov  pf  point_diff
# 0        9    23   32   30    7    9   13  23          -4
# 1       16    32   48   22    9    3   23  22           4
# 2       10    32   42   25   13    6   11  23          12
# 3       15    27   42   26    4    4   20  16         -12
# 4       19    26   45   27   11    6   10  16         -29
# ...    ...   ...  ...  ...  ...  ...  ...  ..         ...
# 2455    12    34   46   29    9    5    8  21           1
# 2456     5    39   44   19    3    9   13  17         -23
# 2457    13    41   54   25    8    9    8  19          23
# 2458     5    40   45   21    7    4   18  25          -7
# 2459     9    41   50   30    9    2   17  18           7
#
# [2460 rows x 21 columns]

# %% [markdown]
# ### Combine DataFrames

# %%
# Create "matches" for the usuable match up data
matches = nba_df[["team", "w_l", "type", "opponent"]].copy()
matches = matches.dropna()

# Merge Agg Data with Abbv to create a dataframe with the aggregate data and the team abbreviation
reg_season_abbv = reg_season_compiled.merge(name_abbv, how = "left", left_on = "team", right_on = "team_name")

# Drop the full team names in favor of the abbv
reg_season_abbv = reg_season_abbv.drop(["team", "team_name"], axis = 1)

# Distinguish Opponent Data from "Defending" Team Data
oppo_reg_season_abbv = reg_season_abbv.add_prefix('OPPO_')

# Merge Team Agg Info with Match Info, twice... Once for defending team, once for opponent
team_games_data = matches.merge(reg_season_abbv, how = "left", left_on = "team", right_on = "abbreviation").merge(oppo_reg_season_abbv, how = "left", left_on = "opponent", right_on = "OPPO_abbreviation")

# Drop target and superfluous columns
team_games_data = team_games_data.drop(["abbreviation", "OPPO_abbreviation"], axis = 1)

# Adding in post-season data:
if use_post_season == "yes":
    
    # Create "post_matches" for the usuable post season match up data
    post_matches = nba_post[["team", "w_l", "type", "opponent"]].copy()
    post_matches = post_matches.dropna()
    
    # Merge Agg Data with Abbv to create a dataframe with the aggregate data and the team abbreviation
    post_season_abbv = post_season_compiled.merge(name_abbv, how = "left", left_on = "team", right_on = "team_name")
    
    # Drop the full team names in favor of the abbv
    post_season_abbv = post_season_abbv.drop(["team", "team_name"], axis = 1)
       
    # Distinguish Opponent Data from "Defending" Team Data
    oppo_post_season_abbv = post_season_abbv.add_prefix('OPPO_')
    
    # Merge Team Agg Info with Match Info, twice... Once for defending team, once for opponent
    post_games_data = post_matches.merge(post_season_abbv, how = "left", left_on = "team", right_on = "abbreviation").merge(oppo_post_season_abbv, how = "left", left_on = "opponent", right_on = "OPPO_abbreviation")
    
    # Drop target and superfluous columns
    post_games_data = post_games_data.drop(["abbreviation", "OPPO_abbreviation"], axis = 1)

    # This is effectively dropping play-in matches until/unless we have play-in stats
    post_games_data = post_games_data.dropna()
    
    # These columns are getting dropped until/unless placeholders can be calculated for items the regular season has that play-off do not. Strength of Schedule, Margin of Victory
    team_games_data = team_games_data.drop(['sos', 'OPPO_srs', 'OPPO_mov', 'OPPO_sos', 'OPPO_attend_g', 'srs', 'attend_g', 'mov'], axis = 1)
    
    # Make the column orders match
    columns = list(team_games_data.columns)
    post_games_data = post_games_data[columns].copy()
    
    # Concat post season games date and regular season games data
    team_games_data = pd.concat([post_games_data, team_games_data], ignore_index=True)
team_games_data
# Out:
#      team w_l type opponent     mp  off_fg  off_fga  off_fg_percent  off_3p  \
# 0     GSW   W   vs      BOS  240.0    42.1     85.9           0.490    13.8
# 1     BOS   L    @      GSW  240.0    37.3     81.7           0.457    13.8
# 2     GSW   L   vs      BOS  240.0    42.1     85.9           0.490    13.8
# 3     BOS   W    @      GSW  240.0    37.3     81.7           0.457    13.8
# 4     MIA   L   vs      BOS  240.0    38.0     85.3           0.445    10.9
# ...   ...  ..  ...      ...    ...     ...      ...             ...     ...
# 2625  CHA   W    @      IND  242.4    42.8     91.4           0.468    13.9
# 2626  BKN   L   vs      MIL  240.9    42.0     88.4           0.475    11.5
# 2627  MIL   W    @      BKN  240.9    41.8     89.4           0.468    14.1
# 2628  LAL   L   vs      GSW  243.7    41.6     88.8           0.469    12.0
# 2629  GSW   W    @      LAL  240.6    40.5     86.4           0.469    14.3
#
#       off_3pa  ...  OPPO_three_par  OPPO_ts_percent  OPPO_off_efg_percent  \
# 0        36.2  ...           0.457            0.584                 0.541
# 1        37.3  ...           0.421            0.599                 0.571
# 2        36.2  ...           0.457            0.584                 0.541
# 3        37.3  ...           0.421            0.599                 0.571
# 4        34.8  ...           0.457            0.584                 0.541
# ...       ...  ...             ...              ...                   ...
# 2625     38.2  ...           0.395            0.564                 0.531
# 2626     31.7  ...           0.430            0.580                 0.546
# 2627     38.4  ...           0.359            0.576                 0.540
# 2628     34.5  ...           0.456            0.582                 0.552
# 2629     39.4  ...           0.388            0.567                 0.537
#
#       OPPO_off_tov_percent  OPPO_off_orb_percent  OPPO_off_ft_fga  \
# 0                     13.1                  21.4            0.236
# 1                     13.4                  24.2            0.187
# 2                     13.1                  21.4            0.236
# 3                     13.4                  24.2            0.187
# 4                     13.1                  21.4            0.236
# ...                    ...                   ...              ...
# 2625                  12.7                  25.5            0.184
# 2626                  11.9                  23.0            0.199
# 2627                  12.5                  23.9            0.198
# 2628                  13.5                  22.8            0.181
# 2629                  12.8                  21.1            0.190
#
#       OPPO_def_efg_percent  OPPO_def_tov_percent  OPPO_def_drb_percent  \
# 0                    0.493                  12.1                  76.5
# 1                    0.529                  11.6                  77.8
# 2                    0.493                  12.1                  76.5
# 3                    0.529                  11.6                  77.8
# 4                    0.493                  12.1                  76.5
# ...                    ...                   ...                   ...
# 2625                 0.552                  11.9                  76.2
# 2626                 0.536                  11.6                  78.6
# 2627                 0.521                  11.7                  75.1
# 2628                 0.509                  13.0                  78.7
# 2629                 0.540                  12.2                  75.8
#
#       OPPO_def_ft_fga
# 0               0.193
# 1               0.211
# 2               0.193
# 3               0.211
# 4               0.193
# ...               ...
# 2625            0.204
# 2626            0.165
# 2627            0.201
# 2628            0.201
# 2629            0.192
#
# [2630 rows x 130 columns]

# %%
# Confirm a lack of differences in columns
if use_post_season == "yes":
    print(list(set(team_games_data.columns) - set(post_games_data.columns))) # Regular Season has these, Post Season doesn't
    print(list(set(post_games_data.columns) - set(team_games_data.columns)))
# Out:
# []
# []

# %%
team_games_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2630 entries, 0 to 2629
# Columns: 130 entries, team to OPPO_def_ft_fga
# dtypes: float64(126), object(4)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Visualizing Features

# %%
# Create dataframe for only the numerical columns
num_df = team_games_data.select_dtypes(include = np.number)
corr = num_df.corr()

# Correlation map without the correlation values shown

# f, ax = plt.subplots(figsize=(20, 20))
# sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax);
# plt.savefig("Visuals/heatmap.jpeg")

# %%
# Correlation map with the correlation values shown
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c52a7_row0_col0, #T_c52a7_row1_col1, #T_c52a7_row2_col2, #T_c52a7_row3_col3, #T_c52a7_row4_col4, #T_c52a7_row5_col5, #T_c52a7_row6_col6, #T_c52a7_row7_col7, #T_c52a7_row8_col8, #T_c52a7_row9_col9, #T_c52a7_row10_col10, #T_c52a7_row11_col11, #T_c52a7_row12_col12, #T_c52a7_row13_col13, #T_c52a7_row14_col14, #T_c52a7_row15_col15, #T_c52a7_row16_col16, #T_c52a7_row17_col17, #T_c52a7_row18_col18, #T_c52a7_row19_col19, #T_c52a7_row20_col20, #T_c52a7_row21_col21, #T_c52a7_row22_col22, #T_c52a7_row23_col23, #T_c52a7_row24_col24, #T_c52a7_row25_col25, #T_c52a7_row26_col26, #T_c52a7_row27_col27, #T_c52a7_row28_col28, #T_c52a7_row29_col29, #T_c52a7_row30_col30, #T_c52a7_row31_col31, #T_c52a7_row32_col32, #T_c52a7_row33_col33, #T_c52a7_row34_col34, #T_c52a7_row35_col35, #T_c52a7_row36_col36, #T_c52a7_row37_col37, #T_c52a7_row38_col38, #T_c52a7_row39_col39, #T_c52a7_row40_col40, #T_c52a7_row41_col41, #T_c52a7_row42_col42, #T_c52a7_row43_col43, #T_c52a7_row44_col44, #T_c52a7_row45_col45, #T_c52a7_row46_col46, #T_c52a7_row47_col47, #T_c52a7_row48_col48, #T_c52a7_row49_col49, #T_c52a7_row50_col50, #T_c52a7_row51_col51, #T_c52a7_row52_col52, #T_c52a7_row53_col53, #T_c52a7_row54_col54, #T_c52a7_row55_col55, #T_c52a7_row56_col56, #T_c52a7_row57_col57, #T_c52a7_row58_col58, #T_c52a7_row59_col59, #T_c52a7_row60_col60, #T_c52a7_row61_col61, #T_c52a7_row62_col62, #T_c52a7_row63_col63, #T_c52a7_row64_col64, #T_c52a7_row65_col65, #T_c52a7_row66_col66, #T_c52a7_row67_col67, #T_c52a7_row68_col68, #T_c52a7_row69_col69, #T_c52a7_row70_col70, #T_c52a7_row71_col71, #T_c52a7_row72_col72, #T_c52a7_row73_col73, #T_c52a7_row74_col74, #T_c52a7_row75_col75, #T_c52a7_row76_col76, #T_c52a7_row77_col77, #T_c52a7_row78_col78, #T_c52a7_row79_col79, #T_c52a7_row80_col80, #T_c52a7_row81_col81, #T_c52a7_row82_col82, #T_c52a7_row83_col83, #T_c52a7_row84_col84, #T_c52a7_row85_col85, #T_c52a7_row86_col86, #T_c52a7_row87_col87, #T_c52a7_row88_col88, #T_c52a7_row89_col89, #T_c52a7_row90_col90, #T_c52a7_row91_col91, #T_c52a7_row92_col92, #T_c52a7_row93_col93, #T_c52a7_row94_col94, #T_c52a7_row95_col95, #T_c52a7_row96_col96, #T_c52a7_row97_col97, #T_c52a7_row98_col98, #T_c52a7_row99_col99, #T_c52a7_row100_col100, #T_c52a7_row101_col101, #T_c52a7_row102_col102, #T_c52a7_row103_col103, #T_c52a7_row104_col104, #T_c52a7_row105_col105, #T_c52a7_row106_col106, #T_c52a7_row107_col107, #T_c52a7_row108_col108, #T_c52a7_row109_col109, #T_c52a7_row110_col110, #T_c52a7_row111_col111, #T_c52a7_row112_col112, #T_c52a7_row113_col113, #T_c52a7_row114_col114, #T_c52a7_row115_col115, #T_c52a7_row116_col116, #T_c52a7_row117_col117, #T_c52a7_row118_col118, #T_c52a7_row119_col119, #T_c52a7_row120_col120, #T_c52a7_row121_col121, #T_c52a7_row122_col122, #T_c52a7_row123_col123, #T_c52a7_row124_col124, #T_c52a7_row125_col125 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c52a7_row0_col1, #T_c52a7_row0_col68, #T_c52a7_row0_col77, #T_c52a7_row1_col85, #T_c52a7_row2_col78, #T_c52a7_row3_col67, #T_c52a7_row4_col68, #T_c52a7_row5_col9, #T_c52a7_row5_col38, #T_c52a7_row6_col112, #T_c52a7_row7_col61, #T_c52a7_row7_col92, #T_c52a7_row8_col77, #T_c52a7_row8_col113, #T_c52a7_row9_col67, #T_c52a7_row11_col43, #T_c52a7_row13_col34, #T_c52a7_row13_col67, #T_c52a7_row13_col105, #T_c52a7_row13_col107, #T_c52a7_row13_col112, #T_c52a7_row13_col113, #T_c52a7_row14_col36, #T_c52a7_row17_col105, #T_c52a7_row17_col107, #T_c52a7_row17_col112, #T_c52a7_row19_col58, #T_c52a7_row21_col53, #T_c52a7_row22_col92, #T_c52a7_row22_col99, #T_c52a7_row22_col112, #T_c52a7_row23_col44, #T_c52a7_row23_col114, #T_c52a7_row24_col68, #T_c52a7_row24_col113, #T_c52a7_row25_col13, #T_c52a7_row26_col43, #T_c52a7_row26_col67, #T_c52a7_row26_col98, #T_c52a7_row27_col68, #T_c52a7_row28_col89, #T_c52a7_row29_col48, #T_c52a7_row31_col37, #T_c52a7_row31_col70, #T_c52a7_row32_col2, #T_c52a7_row33_col112, #T_c52a7_row34_col67, #T_c52a7_row35_col67, #T_c52a7_row35_col105, #T_c52a7_row36_col78, #T_c52a7_row36_col111, #T_c52a7_row37_col19, #T_c52a7_row37_col32, #T_c52a7_row37_col85, #T_c52a7_row39_col5, #T_c52a7_row39_col29, #T_c52a7_row39_col32, #T_c52a7_row40_col42, #T_c52a7_row40_col108, #T_c52a7_row41_col33, #T_c52a7_row41_col112, #T_c52a7_row41_col115, #T_c52a7_row44_col64, #T_c52a7_row45_col26, #T_c52a7_row46_col64, #T_c52a7_row48_col41, #T_c52a7_row49_col11, #T_c52a7_row49_col113, #T_c52a7_row50_col98, #T_c52a7_row50_col112, #T_c52a7_row52_col83, #T_c52a7_row52_col97, #T_c52a7_row53_col38, #T_c52a7_row53_col112, #T_c52a7_row54_col110, #T_c52a7_row56_col112, #T_c52a7_row56_col113, #T_c52a7_row57_col62, #T_c52a7_row58_col83, #T_c52a7_row58_col94, #T_c52a7_row59_col33, #T_c52a7_row59_col53, #T_c52a7_row59_col58, #T_c52a7_row59_col113, #T_c52a7_row60_col112, #T_c52a7_row61_col67, #T_c52a7_row62_col47, #T_c52a7_row62_col106, #T_c52a7_row63_col5, #T_c52a7_row63_col14, #T_c52a7_row63_col64, #T_c52a7_row64_col22, #T_c52a7_row65_col15, #T_c52a7_row66_col4, #T_c52a7_row67_col5, #T_c52a7_row68_col72, #T_c52a7_row68_col101, #T_c52a7_row69_col49, #T_c52a7_row70_col29, #T_c52a7_row70_col124, #T_c52a7_row71_col14, #T_c52a7_row71_col50, #T_c52a7_row72_col4, #T_c52a7_row74_col106, #T_c52a7_row76_col4, #T_c52a7_row76_col42, #T_c52a7_row76_col44, #T_c52a7_row76_col49, #T_c52a7_row76_col50, #T_c52a7_row76_col97, #T_c52a7_row77_col99, #T_c52a7_row80_col42, #T_c52a7_row80_col44, #T_c52a7_row80_col49, #T_c52a7_row82_col121, #T_c52a7_row84_col116, #T_c52a7_row85_col29, #T_c52a7_row85_col36, #T_c52a7_row85_col49, #T_c52a7_row86_col51, #T_c52a7_row86_col107, #T_c52a7_row87_col5, #T_c52a7_row87_col50, #T_c52a7_row88_col76, #T_c52a7_row89_col4, #T_c52a7_row89_col35, #T_c52a7_row89_col106, #T_c52a7_row90_col5, #T_c52a7_row91_col26, #T_c52a7_row92_col111, #T_c52a7_row94_col7, #T_c52a7_row94_col100, #T_c52a7_row95_col65, #T_c52a7_row96_col49, #T_c52a7_row97_col4, #T_c52a7_row98_col4, #T_c52a7_row98_col42, #T_c52a7_row99_col15, #T_c52a7_row99_col48, #T_c52a7_row100_col22, #T_c52a7_row100_col82, #T_c52a7_row100_col95, #T_c52a7_row102_col68, #T_c52a7_row102_col92, #T_c52a7_row102_col95, #T_c52a7_row103_col45, #T_c52a7_row103_col105, #T_c52a7_row104_col49, #T_c52a7_row104_col52, #T_c52a7_row104_col96, #T_c52a7_row107_col1, #T_c52a7_row108_col89, #T_c52a7_row109_col1, #T_c52a7_row111_col104, #T_c52a7_row112_col50, #T_c52a7_row112_col74, #T_c52a7_row113_col35, #T_c52a7_row113_col49, #T_c52a7_row115_col20, #T_c52a7_row115_col34, #T_c52a7_row116_col49, #T_c52a7_row116_col101, #T_c52a7_row117_col47, #T_c52a7_row119_col49, #T_c52a7_row119_col50, #T_c52a7_row120_col125, #T_c52a7_row121_col20, #T_c52a7_row121_col31, #T_c52a7_row122_col50, #T_c52a7_row122_col96, #T_c52a7_row122_col116, #T_c52a7_row122_col121, #T_c52a7_row123_col49, #T_c52a7_row124_col4, #T_c52a7_row125_col43, #T_c52a7_row125_col110 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c52a7_row0_col2, #T_c52a7_row1_col6, #T_c52a7_row1_col110, #T_c52a7_row8_col22, #T_c52a7_row20_col58, #T_c52a7_row23_col37, #T_c52a7_row25_col45, #T_c52a7_row27_col35, #T_c52a7_row30_col62, #T_c52a7_row36_col28, #T_c52a7_row38_col39, #T_c52a7_row39_col34, #T_c52a7_row41_col49, #T_c52a7_row43_col14, #T_c52a7_row43_col58, #T_c52a7_row52_col49, #T_c52a7_row57_col39, #T_c52a7_row57_col46, #T_c52a7_row58_col12, #T_c52a7_row58_col43, #T_c52a7_row58_col48, #T_c52a7_row59_col31, #T_c52a7_row62_col33, #T_c52a7_row63_col65, #T_c52a7_row64_col47, #T_c52a7_row64_col69, #T_c52a7_row71_col85, #T_c52a7_row83_col121, #T_c52a7_row86_col100, #T_c52a7_row88_col108, #T_c52a7_row90_col98, #T_c52a7_row93_col125, #T_c52a7_row99_col91, #T_c52a7_row101_col102, #T_c52a7_row102_col97, #T_c52a7_row104_col112, #T_c52a7_row106_col77, #T_c52a7_row106_col121, #T_c52a7_row115_col112, #T_c52a7_row120_col102, #T_c52a7_row120_col109, #T_c52a7_row121_col75, #T_c52a7_row121_col106, #T_c52a7_row121_col111, #T_c52a7_row122_col94, #T_c52a7_row125_col96 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_c52a7_row0_col3, #T_c52a7_row0_col40, #T_c52a7_row0_col62, #T_c52a7_

# %% [markdown]
# # Dummies, Scaling, Splitting Data

# %%
# Designate the target values as the winning side of w_l
target = team_games_data["w_l"]

y = pd.get_dummies(target)
y = y["W"]
print(f"Shape of target (y): {y.shape}")

# Designate Features and convert categorical data to numeric with `pd.get_dummies`
features = team_games_data.drop(["w_l"], axis = 1)

X = pd.get_dummies(features)
print(f"Shape of features (X): {X.shape}")
# Out:
# Shape of target (y): (2630,)
# Shape of features (X): (2630, 188)

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Feature Scaling

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### Dimensionality Reduction with PCA (Principal Component Analysis)

# %%
pca_preserve = 0.999

pca = PCA(n_components = pca_preserve)

# Transform training and testing data
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

print(f"Shape of training data after PCA: {X_train_pca.shape}")
print(f"Number of columns reduced from {X_train_scaled.shape[1]} to {X_train_pca.shape[1]}")
print(f"{pca_preserve * 100}% of explained variance preserved")
# Out:
# Shape of training data after PCA: (1972, 82)
# Number of columns reduced from 188 to 82
# 99.9% of explained variance preserved

# %% [markdown]
# # Compile, Train, and Evaluate the Neural Network Models

# %%
# Find Best Model from previous runs - This code finds the first model with the highest accuracy in the list, not all models with the same (shared) highest accuracy

def get_best_saved_model():

    if use_post_season == "yes":
        current_folder = "Post_Season"
    else:
        current_folder = "Reg_Season"

    folder_list = os.listdir(f'Models/{current_folder}')       
    model_list = []
    accu_list = []  
    
    # Compile a list of models
    for file in folder_list:
        first_word = file.split("_")[0]
        if first_word == "NBA":
            model_list.append(file)

    # Exract the accuracy of the models
    for model in model_list:
        model_name = model.split(".")[0]
        model_accu = model_name[-4:]
        accu_list.append(model_accu)

    # Find the index of the best accuracy
    best_saved_accuracy = max(accu_list)
    index = accu_list.index(best_saved_accuracy)
    
    # Get the name of the best saved model
    best_saved_model = model_list[index]
        
    return int(best_saved_accuracy), best_saved_model, current_folder

# %% [markdown]
# Go to <a href=#Parameters>Current Parameters</a>

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_features = len(X_train_pca[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_1, activation = activation_1, input_dim = num_features))

# First dropout layer
nn.add(tf.keras.layers.Dropout(rate = dropout_rate_1, noise_shape=None, seed=None))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_2, activation = activation_2))

# Second dropout layer
nn.add(tf.keras.layers.Dropout(rate = dropout_rate_2, noise_shape=None, seed=None))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_3, activation = activation_3))

# Third dropout layer
nn.add(tf.keras.layers.Dropout(rate = dropout_rate_3, noise_shape=None, seed=None))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units = neurons_4, activation = activation_4))

# Third dropout layer
nn.add(tf.keras.layers.Dropout(rate = dropout_rate_4, noise_shape=None, seed=None))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation = activation_outer))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 27)                2241
#
#  dropout (Dropout)           (None, 27)                0
#
#  dense_1 (Dense)             (None, 10)                280
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  dense_3 (Dense)             (None, 1)                 11
#
#  dropout_3 (Dropout)         (None, 1)                 0
#
#  dense_4 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 2,644
# Trainable params: 2,644
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Specify learning rate and compile the model
opt = keras.optimizers.Adam(learning_rate = alpha)

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer=opt, metrics=["binary_accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_pca, y_train, epochs=num_epochs)
# Out:
# Epoch 1/20
# 62/62 [==============================] - 1s 786us/step - loss: 0.7081 - binary_accuracy: 0.5015
# Epoch 2/20
# 62/62 [==============================] - 0s 745us/step - loss: 0.6898 - binary_accuracy: 0.5390
# Epoch 3/20
# 62/62 [==============================] - 0s 747us/step - loss: 0.6825 - binary_accuracy: 0.5705
# Epoch 4/20
# 62/62 [==============================] - 0s 769us/step - loss: 0.6763 - binary_accuracy: 0.5984
# Epoch 5/20
# 62/62 [==============================] - 0s 768us/step - loss: 0.6745 - binary_accuracy: 0.6019
# Epoch 6/20
# 62/62 [==============================] - 0s 768us/step - loss: 0.6666 - binary_accuracy: 0.6156
# Epoch 7/20
# 62/62 [==============================] - 0s 753us/step - loss: 0.6577 - binary_accuracy: 0.6237
# Epoch 8/20
# 62/62 [==============================] - 0s 768us/step - loss: 0.6537 - binary_accuracy: 0.6395
# Epoch 9/20
# 62/62 [==============================] - 0s 743us/step - loss: 0.6546 - binary_accuracy: 0.6303
# Epoch 10/20
# 62/62 [==============================] - 0s 747us/step - loss: 0.6462 - binary_accuracy: 0.6471
# Epoch 11/20
# 62/62 [==============================] - 0s 757us/step - loss: 0.6412 - binary_accuracy: 0.6567
# Epoch 12/20
# 62/62 [==============================] - 0s 730us/step - loss: 0.6431 - binary_accuracy: 0.6501
# Epoch 13/20
# 62/62 [==============================] - 0s 742us/step - loss: 0.6341 - binary_accuracy: 0.6623
# Epoch 14/20
# 62/62 [==============================] - 0s 768us/step - loss: 0.6376 - binary_accuracy: 0.6613
# Epoch 15/20
# 62/62 [==============================] - 0s 738us/step - loss: 0.6287 - binary_accuracy: 0.6800
# Epoch 16/20
# 62/62 [==============================] - 0s 743us/step - loss: 0.6288 - binary_accuracy: 0.6678
# Epoch 17/20
# 62/62 [==============================] - 0s 737us/step - loss: 0.6262 - binary_accuracy: 0.6765
# Epoch 18/20
# 62/62 [==============================] - 0s 764us/step - loss: 0.6296 - binary_accuracy: 0.6729
# Epoch 19/20
# 62/62 [==============================] - 0s 736us/step - loss: 0.6174 - binary_accuracy: 0.6881
# Epoch 20/20
# 62/62 [==============================] - 0s 768us/step - loss: 0.6198 - binary_accuracy: 0.6897

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
history_df.plot(y="binary_accuracy");

# %%
# Evaluate the model using the test data
current_model_loss, current_model_accuracy = nn.evaluate(X_test_pca, y_test, verbose=0)
print(f"Loss: {current_model_loss}, Accuracy: {current_model_accuracy}")
# Out:
# Loss: 0.6619144678115845, Accuracy: 0.6109422445297241

# %%
# Define best_saved_accuracy so that only models with better accuracy are saved
best_saved_accuracy, best_saved_model, current_folder = get_best_saved_model()

accu_formatted = "{:.2%}".format(current_model_accuracy)
accu = round(current_model_accuracy * 10_000)

model_source = "basic"

# Save and export results to an HDF5 file
if accu > best_saved_accuracy: # best_saved_accuracy
    nn.save(f"Models/{current_folder}/NBA_model_{model_source}{accu}.h5", include_optimizer=False)
    print(f"Model saved with {accu_formatted} accuracy in {current_folder}")
else:
    saved_accu_formatted = "{:.2%}".format(best_saved_accuracy / 10000)
    print(f"The model was not saved as the {accu_formatted} accuracy is not higher than {saved_accu_formatted}.")
# Out:
# The model was not saved as the 61.09% accuracy is not higher than 65.81%.

# %% [markdown]
# Go to <a href=#Parameters>Current Parameters</a>

# %% [markdown]
# # GAME PREDICTION

# %%
# Boston Celtics BOS @ Golden State Warriors GSW

# Test predictions on PHX vs. HOU

team_A = "GSW" #TEAM
game_type = "@" #TYPE
team_B = "BOS" #OPPONENT

d = {"team": team_A, "type": game_type, "opponent": team_B}

current_match = pd.DataFrame(data = d, index=[0])
current_match
# Out:
#   team type opponent
# 0  GSW    @      BOS

# %% [markdown]
# ### Create dataframe that matches the columns from "X_train_pca"

# %%
# Merge aggregate info into the match data frame
if use_post_season == "yes":
    current_game_data = current_match.merge(post_season_abbv, how = "left", left_on = "team", right_on = "abbreviation").merge(oppo_post_season_abbv, how = "left", left_on = "opponent", right_on = "OPPO_abbreviation")
    current_game_data = pd.get_dummies(current_game_data.drop(["abbreviation", "OPPO_abbreviation"], axis = 1))
else:
    current_game_data = current_match.merge(reg_season_abbv, how = "left", left_on = "team", right_on = "abbreviation").merge(oppo_reg_season_abbv, how = "left", left_on = "opponent", right_on = "OPPO_abbreviation")
    current_game_data = pd.get_dummies(current_game_data.drop(["abbreviation", "OPPO_abbreviation"], axis = 1))

# Add missing columns and assign a value of "0" for each
fill_list = list(set(X.columns) - set(current_game_data.columns))

for i in fill_list:
    current_game_data[i] = 0

# Make the column orders match
columns = list(X_train.columns)
current_game_data = current_game_data[columns].copy()

# Scale and PCA transform
X_new = X_scaler.transform(current_game_data)
X_new = pca.transform(X_new)

# Confirm a lack of differences between columns
print(list(set(current_game_data.columns) - set(X_train.columns)))
print(list(set(X_train.columns) - set(current_game_data.columns)))
# Out:
# []
# []

# %% [markdown]
# ## Prediction from the Current Model

# %%
# Use dataframe of current match data to generate prediction - https://machinelearningmastery.com/make-predictions-scikit-learn/
y_new = nn.predict([X_new])

# Format values for print statement
win_chance = "{:.2%}".format(y_new[0][0])
model_accuracy_perc = "{:.2%}".format(current_model_accuracy)

# Print prediction
print(f"{team_A} has a {win_chance} chance to win {game_type} {team_B} according to the current model ({model_accuracy_perc} accuracy).")
# Out:
# 1/1 [==============================] - 0s 65ms/step
# GSW has a 62.40% chance to win @ BOS according to the current model (61.09% accuracy).

# %% [markdown]
# ## Prediction from Best Saved Model

# %%
# Load the model
saved_model = load_model(f"Models/{current_folder}/{best_saved_model}")

# Evaluate the model using the test data
saved_model_loss, saved_model_accuracy = saved_model.evaluate(X_test_pca, y_test, verbose=2)
print(f"{best_saved_model} Loss: {saved_model_loss}, Accuracy: {saved_model_accuracy}\n")

# Calculate prediction
y_new = saved_model.predict([X_new])

# Format values for print statement
win_chance = "{:.2%}".format(y_new[0][0])
model_accuracy_perc = "{:.2%}".format(saved_model_accuracy)

# Print prediction
print(f"{team_A} has a {win_chance} chance to win {game_type} {team_B} according to the best saved model ({model_accuracy_perc} accuracy).")
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 21/21 - 0s - loss: 0.6556 - binary_accuracy: 0.6581 - 82ms/epoch - 4ms/step
# NBA_model_auto6581.h5 Loss: 0.6555619835853577, Accuracy: 0.6580547094345093
#
# 1/1 [==============================] - 0s 31ms/step
# GSW has a 47.07% chance to win @ BOS according to the best saved model (65.81% accuracy).

# %% [markdown]
# # Automated Optimization
# The auto-optimizer will not create new models unless "untitled_project" is deleted/renamed first

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid', 'softmax'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=30,
        step=2), activation=activation, input_dim=num_features))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=35,
            step=3),
            activation=activation))
        # Dropout layer
        nn_model.add(tf.keras.layers.Dropout(rate = dropout_rate_1))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Define optimizer
    opt = keras.optimizers.Adam(learning_rate = alpha)
    
    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["binary_accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_binary_accuracy",
    max_epochs=50,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_pca, y_train, epochs = num_epochs, validation_data=(X_test_pca, y_test))
# Out:
# Trial 180 Complete [00h 00m 04s]
# val_binary_accuracy: 0.6200608015060425
#
# Best val_binary_accuracy So Far: 0.6580547094345093
# Total elapsed time: 00h 04m 29s
# INFO:tensorflow:Oracle triggered exit

# %%
X_train_pca.shape, X_test_pca.shape
# Out:
# ((1972, 82), (658, 82))

# %%
# Get best model hyperparameters
best_hyper = tuner.get_best_hyperparameters()[0]
best_hyper.values
# Out:
# {'activation': 'relu',
#  'first_units': 5,
#  'num_layers': 3,
#  'units_0': 22,
#  'units_1': 28,
#  'units_2': 25,
#  'units_3': 16,
#  'units_4': 13,
#  'units_5': 31,
#  'tuner/epochs': 17,
#  'tuner/initial_epoch': 0,
#  'tuner/bracket': 1,
#  'tuner/round': 0}

# %%
def get_best_model(nn, parameters, X_train_scaled, y_train):
    clf = GridSearchCV(model, parameters, cv=4, n_jobs=-1)
    clf.fit(X_train, y_train)
    # print(clf.best_params_)
    return clf.best_estimator_

# %% [markdown]
# The following cell will start to break if you run it too many times before restarting the kernal

# %%
# Evaluate best model against full test data
best_model = tuner.get_best_models(1)[0]
auto_model_loss, auto_model_accuracy = best_model.evaluate(X_test_pca, y_test, verbose=2)
print(f"Loss: {auto_model_loss}, Accuracy: {auto_model_accuracy}")
# Out:
# 21/21 - 0s - loss: 0.6406 - binary_accuracy: 0.6581 - 140ms/epoch - 7ms/step
# Loss: 0.6405600905418396, Accuracy: 0.6580547094345093

# %%
# Define best_saved_accuracy so that only models with better accuracy are saved
best_saved_accuracy, best_saved_model, current_folder = get_best_saved_model()

accu_formatted = "{:.2%}".format(auto_model_accuracy)
accu = round(auto_model_accuracy * 10_000)

model_source = "auto"

# Save and export results to an HDF5 file
if accu > best_saved_accuracy: # or use best_saved_accuracy
    best_model.save(f"Models/{current_folder}/NBA_model_{model_source}{accu}.h5")
    print(f"Model saved with {accu_formatted} accuracy in {current_folder}")
else:
    saved_accu_formatted = "{:.2%}".format(best_saved_accuracy / 10000)
    print(f"The model was not saved as the {accu_formatted} accuracy is not higher than {saved_accu_formatted}.")
# Out:
# The model was not saved as the 65.81% accuracy is not higher than 65.81%.

# %% [markdown]
# # SAVE EXPERIMENT - Verify Save and Reload

# %%
save_test = best_model
test_model_loss, test_model_accuracy = save_test.evaluate(X_test_pca, y_test, verbose=2)
print(f"Loss: {test_model_loss}, Accuracy: {test_model_accuracy}")
save_test.save("Models/save_test.h5")

load_test = load_model("Models/save_test.h5")
test_model_loss, test_model_accuracy = load_test.evaluate(X_test_pca, y_test, verbose=2)
print(f"Loss: {test_model_loss}, Accuracy: {test_model_accuracy}")

test_accu = round(test_model_accuracy * 10000)

best_model.save(f"Models/{current_folder}/NBA_model_{model_source}{accu}.h5")
load_test_2 = load_model(f"Models/Reg_Season/NBA_model_auto{test_accu}.h5")
test_model_loss, test_model_accuracy = load_test_2.evaluate(X_test_pca, y_test, verbose=2)
print(f"Loss: {test_model_loss}, Accuracy: {test_model_accuracy}")
# Out:
# 21/21 - 0s - loss: 0.6406 - binary_accuracy: 0.6581 - 22ms/epoch - 1ms/step
# Loss: 0.6405600905418396, Accuracy: 0.6580547094345093
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 21/21 - 0s - loss: 0.6406 - binary_accuracy: 0.6581 - 89ms/epoch - 4ms/step
# Loss: 0.6405600905418396, Accuracy: 0.6580547094345093
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [36], in <cell line: 13>()
#      10 test_accu = round(test_model_accuracy * 10000)
#      12 best_model.save(f"Models/{current_folder}/NBA_model_{model_source}{accu}.h5")
# ---> 13 load_test_2 = load_model(f"Models/Reg_Season/NBA_model_auto{test_accu}.h5")
#      14 test_model_loss, test_model_accuracy = load_test_2.evaluate(X_test_pca, y_test, verbose=2)
#      15 print(f"Loss: {test_model_loss}, Accuracy: {test_model_accuracy}")
#
# File ~\anaconda3\envs\tf2\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\envs\tf2\lib\site-packages\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204 if isinstance(filepath_str, str):
#     205   if not tf.io.gfile.exists(filepath_str):
# --> 206     raise IOError(f'No file or directory found at {filepath_str}')
#     208   if tf.io.gfile.isdir(filepath_str):
#     209     return saved_model_load.load(filepath_str, compile, options)
#
# OSError: No file or directory found at Models/Reg_Season/NBA_model_auto6581.h5

# %% [markdown]
# ## Auto-Optimizer Prediction

# %%
y_auto_model = best_model.predict([X_new])

win_chance = "{:.2%}".format(y_auto_model[0][0])
model_accuracy_perc = "{:.2%}".format(auto_model_accuracy)

print(f"{team_A} has a {win_chance} chance to win {game_type} {team_B} according to the best auto-optimized model ({model_accuracy_perc} accuracy).")
# Out:
# 1/1 [==============================] - 0s 43ms/step
# GSW has a 55.94% chance to win @ BOS according to the best auto-optimized model (65.81% accuracy).

# %% [markdown]
# # Alternate Experiments

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
y_true = y_test
y_pred = saved_model.predict(X_test_pca)
# Out:
# 20/20 [==============================] - 0s 735us/step

# %% [markdown]
# https://www.geeksforgeeks.org/svm-hyperparameter-tuning-using-gridsearchcv-ml/

# %%
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 5>()
#       2 from sklearn.model_selection import GridSearchCV
#       3 param_grid = {'C': [1, 5, 10],
#       4               'gamma': [0.0001, 0.001, 0.01]}
# ----> 5 grid = GridSearchCV(model, param_grid, verbose=3)
#
# NameError: name 'model' is not defined

# %%
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END .................C=1, gamma=0.0001;, score=0.559 total time=   0.3s
# [CV 2/5] END .................C=1, gamma=0.0001;, score=0.615 total time=   0.2s
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.581 total time=   0.3s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.627 total time=   0.2s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=0.619 total time=   0.2s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.559 total time=   0.3s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.615 total time=   0.2s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.581 total time=   0.3s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.627 total time=   0.2s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.619 total time=   0.2s
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.559 total time=   0.2s
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.615 total time=   0.2s
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.581 total time=   0.3s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.627 total time=   0.2s
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.619 total time=   0.2s
# [CV 1/5] END .................C=5, gamma=0.0001;, score=0.559 total time=   1.7s
# [CV 2/5] END .................C=5, gamma=0.0001;, score=0.615 total time=   2.4s
# [CV 3/5] END .................C=5, gamma=0.0001;, score=0.581 total time=   5.2s
# [CV 4/5] END .................C=5, gamma=0.0001;, score=0.627 total time=   1.7s
# [CV 5/5] END .................C=5, gamma=0.0001;, score=0.619 total time=   4.1s
# [CV 1/5] END ..................C=5, gamma=0.001;, score=0.559 total time=   1.7s
# [CV 2/5] END ..................C=5, gamma=0.001;, score=0.615 total time=   2.4s
# [CV 3/5] END ..................C=5, gamma=0.001;, score=0.581 total time=   5.3s
# [CV 4/5] END ..................C=5, gamma=0.001;, score=0.627 total time=   1.7s
# [CV 5/5] END ..................C=5, gamma=0.001;, score=0.619 total time=   4.1s
# [CV 1/5] END ...................C=5, gamma=0.01;, score=0.559 total time=   1.7s
# [CV 2/5] END ...................C=5, gamma=0.01;, score=0.615 total time=   2.4s
# [CV 3/5] END ...................C=5, gamma=0.01;, score=0.581 total time=   5.2s
# [CV 4/5] END ...................C=5, gamma=0.01;, score=0.627 total time=   1.7s
# [CV 5/5] END ...................C=5, gamma=0.01;, score=0.619 total time=   4.1s
# [CV 1/5] END ................C=10, gamma=0.0001;, score=0.559 total time=  54.9s
# [CV 2/5] END ................C=10, gamma=0.0001;, score=0.615 total time=  47.6s
# [CV 3/5] END ................C=10, gamma=0.0001;, score=0.581 total time= 1.2min
# [CV 4/5] END ................C=10, gamma=0.0001;, score=0.627 total time=  35.4s
# [CV 5/5] END ................C=10, gamma=0.0001;, score=0.619 total time=  48.1s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.559 total time=  54.9s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.615 total time=  46.3s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.581 total time= 1.2min
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.627 total time=  35.7s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.619 total time=  47.9s
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.559 total time=  54.9s
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.615 total time=  45.8s
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.581 total time= 1.2min
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.627 total time=  35.4s
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.619 total time=  47.3s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              verbose=3)

# %%
model = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)
# Out:
# C:\Users\emera\AppData\Local\Temp\ipykernel_7596\2457478790.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)

# %%
# activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
# param_grid = dict(activation=activation)


# param_grid = dict(epochs=[10, 20, 30])
# grid = GridSearchCV(estimator=model, param_grid = param_grid, n_jobs=-1, cv=3)
# grid_result = grid.fit(X_train, y_train)

# %% [markdown]
# ### Support-Vector Machine (SVM)

# %%
from sklearn.svm import SVC 
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_pca, y_train)
svm_model.score(X_test_pca, y_test)
# Out:
# 0.6130081300813008

# %%
svm_model.predict(X_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 svm_model.predict(X_new)
#
# NameError: name 'X_new' is not defined

# %% [markdown]
# ### RandomForestsClassifier

# %%
rfc = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_pca, y_train)

# %%
print(f'Training Score: {rfc.score(X_train_pca, y_train)}')
print(f'Testing Score: {rfc.score(X_test_pca, y_test)}')
# Out:
# Training Score: 0.8563685636856369
# Testing Score: 0.6048780487804878

# %%
flatten=[]
for x in range(X_new[0].size):
    flatten.append(X_new[0][x])
#print(test)
y_rfc = rfc.predict([flatten])
y_rfc
# Out:
# array([0], dtype=uint8)

# %%
features = rfc.feature_importances_
# print(features)
plt.bar(x = range(len(features)), height=features)
plt.show()

# %%
features = sorted(zip(X.columns, rfc.feature_importances_), key = lambda x: x[1])
cols = [f[0] for f in features]
width = [f[1] for f in features]

fig, ax = plt.subplots()

fig.set_size_inches(10,200)
plt.margins(y=0.001)

ax.barh(y=cols, width=width)

plt.show()

# %%
# Attempt Feature Selection

from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(rfc)
sel.fit(X_train_scaled, y_train)
sel.get_support()
# Out:
# array([False,  True,  True,  True, False,  True,  True,  True,  True,
#         True, False,  True,  True, False, False, False,  True, False,
#        False, False,  True,  True,  True,  True, False,  True,  True,
#         True,  True, False,  True, False, False,  True, False,  True,
#         True,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False,  True,  True,  True, False, False, False,  True,
#        False,  True, False,  True, False,  True, False,  True, False,
#         True,  True, False,  True, False, False, False,  True, False,
#         True, False, False,  True, False, False,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True, False, False,
#         True,  True, False,  True, False,  True,  True, False,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False,  True,  True,  True,
#         True,  True, False,  True, False,  True, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
X_selected_train, X_selected_test, y_train, y_test = train_test_split(sel.transform(X), y, random_state=1)

scaler = StandardScaler().fit(X_selected_train)

X_selected_train_scaled = scaler.transform(X_selected_train)
X_selected_test_scaled = scaler.transform(X_selected_test)
# Out:
# C:\Users\emera\anaconda3\envs\tf2\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
clf = LogisticRegression()
clf.fit(X_selected_train_scaled, y_train)
print(f'Training Score: {clf.score(X_selected_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_selected_test_scaled, y_test)}')
# Out:
# Training Score: 0.6601626016260163
# Testing Score: 0.6634146341463415
# C:\Users\emera\anaconda3\envs\tf2\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
test=[]
for x in range(X_new[0].size):
    test.append(X_new[0][x])
#print(test)
y_rfc = rfc.predict([test])
y_rfc
# Out:
# array([1], dtype=uint8)

# %%
y_rfc = rfc.predict([X_new])
y_rfc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 y_rfc = rfc.predict([X_new])
#       2 y_rfc
#
# File ~\anaconda3\envs\tf2\lib\site-packages\sklearn\ensemble\_forest.py:808, in ForestClassifier.predict(self, X)
#     787 def predict(self, X):
#     788     """
#     789     Predict class for X.
#     790
#    (...)
#     806         The predicted classes.
#     807     """
# --> 808     proba = self.predict_proba(X)
#     810     if self.n_outputs_ == 1:
#     811         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File ~\anaconda3\envs\tf2\lib\site-packages\sklearn\ensemble\_forest.py:850, in ForestClassifier.predict_proba(self, X)
#     848 check_is_fitted(self)
#     849 # Check data
# --> 850 X = self._validate_X_predict(X)
#     852 # Assign chunk of trees to jobs
#     853 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\envs\tf2\lib\site-packages\sklearn\ensemble\_forest.py:579, in BaseForest._validate_X_predict(self, X)
#     576 """
#     577 Validate X whenever one tries to predict, apply, predict_proba."""
#     578 check_is_fitted(self)
# --> 579 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     580 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     581     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~\anaconda3\envs\tf2\lib\site-packages\sklearn\base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~\anaconda3\envs\tf2\lib\site-packages\sklearn\utils\validation.py:794, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     789         raise ValueError(
#     790             "Unable to convert array of bytes/strings "
#     791             "into decimal numbers with dtype='numeric'"
#     792         ) from e
#     793 if not allow_nd and array.ndim >= 3:
# --> 794     raise ValueError(
#     795         "Found array with dim %d. %s expected <= 2."
#     796         % (array.ndim, estimator_name)
#     797     )
#     799 if force_all_finite:
#     800     _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %% [markdown]
# # OLD HOMEWORK STARTS HERE

# %%
# Create a callback that saves the model's weights every 5 epochs.
saves = 5
mc = keras.callbacks.ModelCheckpoint('Optimized_Weights/weights{epoch:08d}.h5', save_weights_only=True, save_freq=saves, verbose = 0)

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=num_epochs, callbacks=[mc])
