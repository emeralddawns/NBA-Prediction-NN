# %% [markdown]
# # Web Scrape NBA Game Data

# %%
# Import dependencies
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By

# %%
# Create a Web Driver Object
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/110.0.5481.77/chromedriver_win32.zip
# ...

# %% [markdown]
# ## Pull Regular Season Data

# %%
# Connect to the website
driver.get(url="https://www.nba.com/stats/teams/boxscores/?Season=2021-22&SeasonType=Regular%20Season")

# %%
# Select the drop down element that allows user to choose which page to view
select = Select(driver.find_element(By.CLASS_NAME, "DropDown_select__4pIg9"))

# %%
# Select the "ALL" option, which is Index 0
select.select_by_index(0)

# %%
# Read the game stats table on the webpage
tbl = driver.find_element(By.CLASS_NAME, "Crom_table__p1iZz").get_attribute('outerHTML')

# %%
# Convert the table (list) into a DataFrame
result = pd.read_html(tbl)

# %%
# Pull the table into a DataFrame
table_df = result[0]
table_df
# Out:
#      Team     Match Up   Game Date W/L  MIN  PTS  FGM  FGA   FG%  3PM  ...  \
# 0     ORL  ORL vs. NYK  02/06/2023   L  240   98   37   79  46.8    6  ...
# 1     NYK    NYK @ ORL  02/06/2023   W  240  102   37   81  45.7   15  ...
# 2     LAL  LAL vs. OKC  02/06/2023   L  240  130   49   85  57.6   14  ...
# 3     OKC    OKC @ LAL  02/06/2023   W  240  133   49   94  52.1   17  ...
# 4     MIN    MIN @ DEN  02/06/2023   L  240  112   40   85  47.1   10  ...
# ...   ...          ...         ...  ..  ...  ...  ...  ...   ...  ...  ...
# 1635  WAS    WAS @ IND  10/18/2022   W  240  114   42   92  45.7   11  ...
# 1636  BOS  BOS vs. PHI  10/17/2022   W  240  126   46   82  56.1   12  ...
# 1637  LAL    LAL @ GSW  10/17/2022   L  240  109   40   94  42.6   10  ...
# 1638  GSW  GSW vs. LAL  10/17/2022   W  240  123   45   99  45.5   16  ...
# 1639  PHI    PHI @ BOS  10/17/2022   L  240  117   40   80  50.0   13  ...
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV  PF  +/-
# ...

# %%
# Drop unnecessary columns
table_df = table_df.drop(['Match Up', 'Game Date', 'W/L', 'FG%', '3P%', 'FT%'], axis=1)

# %%
# Rename the columns to match the database schema
table_df = table_df.rename(columns={"Team":"team"})
table_df = table_df.rename(columns={"MIN":"min", "PTS":"pts", "FGM":"fgm"})
table_df = table_df.rename(columns={"FGA":"fga", "3PM":"threepm", "3PA":"threepa", "FTM":"ftm", "FTA":"fta"})
table_df = table_df.rename(columns={"OREB":"oreb", "DREB":"dreb", "REB":"reb", "AST":"ast", "STL":"stl"})
table_df = table_df.rename(columns={"BLK":"blk", "TOV":"tov", "PF":"pf", "+/-":"point_diff"})

# %%
# Export the dataframe into a CSV file
table_df.to_csv("Data/Scraped/NBA_Data_Reg_Season_2022.csv")

# %% [markdown]
# ## Pull Play-In Data

# %%
# Connect to the website
driver.get(url="https://www.nba.com/stats/teams/boxscores/?Season=2021-22&SeasonType=PlayIn")

# %%
# Read the table on the webpage
tbl = driver.find_element_by_tag_name("table").get_attribute('outerHTML')
# Out:
# C:\Users\jcbat\AppData\Local\Temp\ipykernel_26636\319274737.py:2: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   tbl = driver.find_element_by_tag_name("table").get_attribute('outerHTML')

# %%
# Convert the table (list) into a DataFrame
result = pd.read_html(tbl)

# %%
# Pull the table into a DataFrame
table_df = result[0]
table_df
# Out:
#    Team     Match Up   Game Date  Season W/L  MIN  PTS  FGM  FGA   FG%  ...  \
# 0   ATL    ATL @ CLE  04/15/2022     NaN   W  240  107   39   80  48.8  ...
# 1   CLE  CLE vs. ATL  04/15/2022     NaN   L  240  101   37   81  45.7  ...
# 2   NOP    NOP @ LAC  04/15/2022     NaN   W  240  105   43   88  48.9  ...
# 3   LAC  LAC vs. NOP  04/15/2022     NaN   L  240  101   35   85  41.2  ...
# 4   ATL  ATL vs. CHA  04/13/2022     NaN   W  240  132   49   94  52.1  ...
# 5   NOP  NOP vs. SAS  04/13/2022     NaN   W  240  113   44   81  54.3  ...
# 6   SAS    SAS @ NOP  04/13/2022     NaN   L  240  103   37   91  40.7  ...
# 7   CHA    CHA @ ATL  04/13/2022     NaN   L  240  103   34   90  37.8  ...
# 8   CLE    CLE @ BKN  04/12/2022     NaN   L  240  108   41   92  44.6  ...
# 9   LAC    LAC @ MIN  04/12/2022     NaN   L  240  104   34   78  43.6  ...
# 10  BKN  BKN vs. CLE  04/12/2022     NaN   W  240  115   45   84  53.6  ...
# ...

# %%
# Drop unnecessary columns
table_df = table_df.drop(['Match\xa0Up', 'Game\xa0Date', 'Season', 'W/L', 'FG%', '3P%', 'FT%'], axis=1)

# %%
# Rename the columns to match the database schema
table_df = table_df.rename(columns={"Team":"team"})
table_df = table_df.rename(columns={"MIN":"min", "PTS":"pts", "FGM":"fgm"})
table_df = table_df.rename(columns={"FGA":"fga", "3PM":"threepm", "3PA":"threepa", "FTM":"ftm", "FTA":"fta"})
table_df = table_df.rename(columns={"OREB":"oreb", "DREB":"dreb", "REB":"reb", "AST":"ast", "STL":"stl"})
table_df = table_df.rename(columns={"BLK":"blk", "TOV":"tov", "PF":"pf", "+/-":"point_diff"})

# %%
# Export the dataframe into a csv file
table_df.to_csv("NBA_Data_Play_In_2022.csv")

# %% [markdown]
# ## Pull Playoff Data

# %%
# Connect to the website
driver.get(url="https://www.nba.com/stats/teams/boxscores/?Season=2021-22&SeasonType=Playoffs")

# %%
# Select the drop down element
select = Select(driver.find_element_by_class_name("stats-table-pagination__select"))
# Out:
# C:\Users\jcbat\AppData\Local\Temp\ipykernel_26636\4141449579.py:2: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   select = Select(driver.find_element_by_class_name("stats-table-pagination__select"))

# %%
# Select the "ALL" option, which is Index 0
select.select_by_index(0)

# %%
# Read the table on the webpage
tbl = driver.find_element_by_tag_name("table").get_attribute('outerHTML')
# Out:
# C:\Users\jcbat\AppData\Local\Temp\ipykernel_26636\319274737.py:2: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   tbl = driver.find_element_by_tag_name("table").get_attribute('outerHTML')

# %%
# Convert the table (list) into a DataFrame
result = pd.read_html(tbl)

# %%
# Pull the table into a DataFrame
table_df = result[0]
table_df
# Out:
#     Team     Match Up   Game Date  Season  W/L  MIN  PTS  FGM  FGA   FG%  ...  \
# 0    GSW    GSW @ BOS  06/08/2022     NaN  NaN    0   11    5   16  31.3  ...
# 1    BOS  BOS vs. GSW  06/08/2022     NaN  NaN    0   26   10   15  66.7  ...
# 2    GSW  GSW vs. BOS  06/05/2022     NaN    W  240  107   39   86  45.3  ...
# 3    BOS    BOS @ GSW  06/05/2022     NaN    L  240   88   30   80  37.5  ...
# 4    GSW  GSW vs. BOS  06/02/2022     NaN    L  240  108   39   88  44.3  ...
# ..   ...          ...         ...     ...  ...  ...  ...  ...  ...   ...  ...
# 163  UTA    UTA @ DAL  04/16/2022     NaN    W  240   99   36   83  43.4  ...
# 164  MEM  MEM vs. MIN  04/16/2022     NaN    L  240  117   39   86  45.3  ...
# 165  MIN    MIN @ MEM  04/16/2022     NaN    W  240  130   45   90  50.0  ...
# 166  GSW  GSW vs. DEN  04/16/2022     NaN    W  240  123   43   82  52.4  ...
# 167  DEN    DEN @ GSW  04/16/2022     NaN    L  240  107   43   93  46.2  ...
#
# ...

# %%
# Drop unnecessary columns
table_df = table_df.drop(['Match\xa0Up', 'Game\xa0Date', 'Season', 'W/L', 'FG%', '3P%', 'FT%'], axis=1)

# %%
# Rename the columns to match the database schema
table_df = table_df.rename(columns={"Team":"team"})
table_df = table_df.rename(columns={"MIN":"min", "PTS":"pts", "FGM":"fgm"})
table_df = table_df.rename(columns={"FGA":"fga", "3PM":"threepm", "3PA":"threepa", "FTM":"ftm", "FTA":"fta"})
table_df = table_df.rename(columns={"OREB":"oreb", "DREB":"dreb", "REB":"reb", "AST":"ast", "STL":"stl"})
table_df = table_df.rename(columns={"BLK":"blk", "TOV":"tov", "PF":"pf", "+/-":"point_diff"})

# %%
# Export the dataframe into a csv file
table_df.to_csv("NBA_Data_Playoffs_2022.csv")
